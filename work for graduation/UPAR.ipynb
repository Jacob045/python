# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
filepath = r'I:\Data\Personal Data\graduation project\SACOL\original_data\200706\sounding_data_as_MWR_format_200706.txt'

# %%
data = pd.read_csv(filepath,sep='  ')
Values = data.columns
print_data = data.iloc[0:1,1:48]
#print(print_data)
a = np.array(print_data).T
b = a.tolist()
print(b)
plt.plot(b,linewidth = 2)
plt.show()
# Out:
# [[286.5045], [287.53], [286.85], [286.11], [284.7591], [285.55], [285.43], [284.9591], [284.4591], [283.5864], [282.7423], [280.5962], [278.6767], [276.4071], [275.3192], [274.4357], [272.6], [270.8577], [270.1143], [268.3429], [266.4214], [265.1192], [263.07], [261.2071], [259.69], [257.9857], [255.65], [253.8367], [251.91], [249.4786], [247.6433], [245.9428], [243.9367], [242.6286], [240.87], [238.9808], [236.9833], [235.3857], [233.4423], [231.3875], [229.15], [227.4233], [225.2808], [223.25], [222.0654], [220.4917], [219.0143]]
